# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

import tensorflow as tf
from tensorflow.keras import layers, models

# %% [markdown]
# ## Load Dataset

# %%
dataset_path = Path("../../dataset")
dl_data_path = dataset_path / "dl_data"

X_train = np.load(dl_data_path / "X_train.npy")
X_validation = np.load(dl_data_path / "X_validation.npy")
X_test = np.load(dl_data_path / "X_test.npy")

y_train = np.load(dl_data_path / "y_train.npy")
y_validation = np.load(dl_data_path / "y_validation.npy")
y_test = np.load(dl_data_path / "y_test.npy")

print("===== Datasets loaded successfully. =====")
# Out:
# ===== Datasets loaded successfully. =====

# %% [markdown]
# ## Preprocessing & Normalization

# %%
X_train = X_train.astype(np.float32)
X_validation = X_validation.astype(np.float32)
X_test = X_test.astype(np.float32)

# Calculate statistics only from training data
train_mean = X_train.mean()
train_std = X_train.std()

# Normalize
X_train = (X_train - train_mean) / train_std
X_validation = (X_validation - train_mean) / train_std
X_test = (X_test - train_mean) / train_std

print("===== NORMALIZATION CHECK =====")

print("Train:")
print("Mean:", X_train.mean())
print("Std:", X_train.std())

print("\nValidation:")
print("Mean:", X_validation.mean())
print("Std:", X_validation.std())

print("\nTest:")
print("Mean:", X_test.mean())
print("Std:", X_test.std())
# Out:
# ===== NORMALIZATION CHECK =====
# Train:
# Mean: 8.628554e-08
# Std: 1.0000006
#
# Validation:
# Mean: 0.00015843338
# Std: 1.0341631
#
# Test:
# Mean: 0.0026376029
# Std: 1.0162377

# %% [markdown]
# ## Add Channel Dimension

# %%
X_train = X_train[..., np.newaxis]
X_validation = X_validation[..., np.newaxis]
X_test = X_test[..., np.newaxis]

print("\n===== BILSTM INPUT SHAPES =====")

print("X_train:", X_train.shape)
print("X_validation:", X_validation.shape)
print("X_test:", X_test.shape)
# Out:
# ===== BILSTM INPUT SHAPES =====
# X_train: (5969, 9000, 1)
# X_validation: (1279, 9000, 1)
# X_test: (1280, 9000, 1)

# %% [markdown]
# ## BiLSTM Model

# %%
inputs = layers.Input(
    shape=(9000, 1)
)

x = inputs


# Initial convolution
x = layers.Conv1D(
    filters=32,
    kernel_size=7,
    padding="same",
    use_bias=False
)(x)

x = layers.BatchNormalization()(x)
x = layers.Activation("relu")(x)


# Downsampling
x = layers.MaxPooling1D(
    pool_size=2
)(x)


# Second convolution
x = layers.Conv1D(
    filters=64,
    kernel_size=5,
    padding="same",
    use_bias=False
)(x)

x = layers.BatchNormalization()(x)
x = layers.Activation("relu")(x)


# Downsampling
x = layers.MaxPooling1D(
    pool_size=2
)(x)


# Third convolution
x = layers.Conv1D(
    filters=128,
    kernel_size=3,
    padding="same",
    use_bias=False
)(x)

x = layers.BatchNormalization()(x)
x = layers.Activation("relu")(x)


# Downsampling
x = layers.MaxPooling1D(
    pool_size=2
)(x)


# BiLSTM
x = layers.Bidirectional(
    layers.LSTM(
        64,
        return_sequences=False
    )
)(x)


# Fully connected layer
x = layers.Dense(
    64,
    activation="relu"
)(x)


# Output layer
outputs = layers.Dense(
    4,
    activation="softmax"
)(x)


model = models.Model(
    inputs=inputs,
    outputs=outputs,
    name="1D_BiLSTM"
)

model.summary()
# Out:
# Model: "1D_BiLSTM"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 9000, 1)]         0
#
#  conv1d (Conv1D)             (None, 9000, 32)          224
#
#  batch_normalization (BatchN  (None, 9000, 32)         128
#  ormalization)
#
#  activation (Activation)     (None, 9000, 32)          0
#
#  max_pooling1d (MaxPooling1D  (None, 4500, 32)         0
#  )
#
#  conv1d_1 (Conv1D)           (None, 4500, 64)          10240
#
#  batch_normalization_1 (Batc  (None, 4500, 64)         256
#  hNormalization)
#
#  activation_1 (Activation)   (None, 4500, 64)          0
#
#  max_pooling1d_1 (MaxPooling  (None, 2250, 64)         0
#  1D)
#
#  conv1d_2 (Conv1D)           (None, 2250, 128)         24576
#
#  batch_normalization_2 (Batc  (None, 2250, 128)        512
#  hNormalization)
#
#  activation_2 (Activation)   (None, 2250, 128)         0
#
#  max_pooling1d_2 (MaxPooling  (None, 1125, 128)        0
#  1D)
#
#  bidirectional (Bidirectiona  (None, 128)              98816
#  l)
#
#  dense (Dense)               (None, 64)                8256
#
#  dense_1 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 143,268
# Trainable params: 142,820
# Non-trainable params: 448
# _________________________________________________________________

# %% [markdown]
# ## Compile Model

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(
        learning_rate=0.001
    ),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

print("Model compiled successfully.")
# Out:
# Model compiled successfully.

# %% [markdown]
# ## Callbacks

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

early_stopping = EarlyStopping(
    monitor="val_loss",
    patience=8,
    restore_best_weights=True,
    verbose=1
)

model_checkpoint = ModelCheckpoint(
    "best_1d_bilstm_unweighted.keras",
    monitor="val_loss",
    save_best_only=True,
    verbose=1
)

print("Callbacks created successfully.")
# Out:
# Callbacks created successfully.

# %% [markdown]
# ## Train Model

# %%
history = model.fit(
    X_train,
    y_train,
    validation_data=(
        X_validation,
        y_validation
    ),
    epochs=50,
    batch_size=8,
    callbacks=[
        early_stopping,
        model_checkpoint
    ],
    verbose=1
)
# Out:
# Epoch 1/50
# 747/747 [==============================] - ETA: 0s - loss: 1.0054 - accuracy: 0.5880
# Epoch 1: val_loss improved from inf to 0.99172, saving model to best_1d_bilstm_unweighted.keras
# 747/747 [==============================] - 173s 189ms/step - loss: 1.0054 - accuracy: 0.5880 - val_loss: 0.9917 - val_accuracy: 0.5950
# Epoch 2/50
# 747/747 [==============================] - ETA: 0s - loss: 0.9843 - accuracy: 0.5936
# Epoch 2: val_loss improved from 0.99172 to 0.96723, saving model to best_1d_bilstm_unweighted.keras
# 747/747 [==============================] - 160s 214ms/step - loss: 0.9843 - accuracy: 0.5936 - val_loss: 0.9672 - val_accuracy: 0.5950
# Epoch 3/50
# 747/747 [==============================] - ETA: 0s - loss: 0.9734 - accuracy: 0.5952
# Epoch 3: val_loss did not improve from 0.96723
# 747/747 [==============================] - 151s 203ms/step - loss: 0.9734 - accuracy: 0.5952 - val_loss: 0.9805 - val_accuracy: 0.5950
# Epoch 4/50
# 747/747 [==============================] - ETA: 0s - loss: 0.9720 - accuracy: 0.5951
# Epoch 4: val_loss improved from 0.96723 to 0.95394, saving model to best_1d_bilstm_unweighted.keras
# 747/747 [==============================] - 161s 216ms/step - loss: 0.9720 - accuracy: 0.5951 - val_loss: 0.9539 - val_accuracy: 0.5950
# Epoch 5/50
# 747/747 [==============================] - ETA: 0s - loss: 0.9612 - accuracy: 0.5959
# Epoch 5: val_loss improved from 0.95394 to 0.95282, saving model to best_1d_bilstm_unweighted.keras
# 747/747 [==============================] - 161s 215ms/step - loss: 0.9612 - accuracy: 0.5959 - val_loss: 0.9528 - val_accuracy: 0.5973
# Epoch 6/50
# 747/747 [==============================] - ETA: 0s - loss: 0.9536 - accuracy: 0.5957
# Epoch 6: val_loss did not improve from 0.95282
# 747/747 [==============================] - 159s 213ms/step - loss: 0.9536 - accuracy: 0.5957 - val_loss: 0.9704 - val_accuracy: 0.5973
# Epoch 7/50
# 747/747 [==============================] - ETA: 0s - loss: 0.9572 - accuracy: 0.5951
# Epoch 7: val_loss improved from 0.95282 to 0.94781, saving model to best_1d_bilstm_unweighted.keras
# 747/747 [==============================] - 155s 207ms/step - loss: 0.9572 - accuracy: 0.5951 - val_loss: 0.9478 - val_accuracy: 0.5981
# Epoch 8/50
# 747/747 [==============================] - ETA: 0s - loss: 0.9451 - accuracy: 0.5976
# Epoch 8: val_loss improved from 0.94781 to 0.94181, saving model to best_1d_bilstm_unweighted.keras
# 747/747 [==============================] - 157s 211ms/step - loss: 0.9451 - accuracy: 0.5976 - val_loss: 0.9418 - val_accuracy: 0.5997
# Epoch 9/50
# 747/747 [==============================] - ETA: 0s - loss: 0.9411 - accuracy: 0.5979
# Epoch 9: val_loss did not improve from 0.94181
# 747/747 [==============================] - 162s 217ms/step - loss: 0.9411 - accuracy: 0.5979 - val_loss: 0.9521 - val_accuracy: 0.5989
# Epoch 10/50
# 747/747 [==============================] - ETA: 0s - loss: 0.9324 - accuracy: 0.5994
# Epoch 10: val_loss improved from 0.94181 to 0.94058, saving model to best_1d_bilstm_unweighted.keras
# 747/747 [==============================] - 161s 215ms/step - loss: 0.9324 - accuracy: 0.5994 - val_loss: 0.9406 - val_accuracy: 0.5981
# Epoch 11/50
# 747/747 [==============================] - ETA: 0s - loss: 0.9319 - accuracy: 0.5994
# Epoch 11: val_loss did not improve from 0.94058
# 747/747 [==============================] - 153s 204ms/step - loss: 0.9319 - accuracy: 0.5994 - val_loss: 0.9460 - val_accuracy: 0.6013
# Epoch 12/50
# 747/747 [==============================] - ETA: 0s - loss: 0.9348 - accuracy: 0.5962
# Epoch 12: val_loss improved from 0.94058 to 0.92355, saving model to best_1d_bilstm_unweighted.keras
# 747/747 [==============================] - 150s 201ms/step - loss: 0.9348 - accuracy: 0.5962 - val_loss: 0.9236 - val_accuracy: 0.6052
# Epoch 13/50
# 747/747 [==============================] - ETA: 0s - loss: 0.9223 - accuracy: 0.6021
# Epoch 13: val_loss improved from 0.92355 to 0.91516, saving model to best_1d_bilstm_unweighted.keras
# 747/747 [==============================] - 159s 213ms/step - loss: 0.9223 - accuracy: 0.6021 - val_loss: 0.9152 - val_accuracy: 0.6044
# Epoch 14/50
# 747/747 [==============================] - ETA: 0s - loss: 0.9198 - accuracy: 0.6050
# Epoch 14: val_loss improved from 0.91516 to 0.90315, saving model to best_1d_bilstm_unweighted.keras
# 747/747 [==============================] - 154s 207ms/step - loss: 0.9198 - accuracy: 0.6050 - val_loss: 0.9031 - val_accuracy: 0.6145
# Epoch 15/50
# 747/747 [==============================] - ETA: 0s - loss: 0.9174 - accuracy: 0.6098
# Epoch 15: val_loss did not improve from 0.90315
# 747/747 [==============================] - 154s 206ms/step - loss: 0.9174 - accuracy: 0.6098 - val_loss: 0.9439 - val_accuracy: 0.6114
# Epoch 16/50
# 747/747 [==============================] - ETA: 0s - loss: 0.9249 - accuracy: 0.6046
# Epoch 16: val_loss did not improve from 0.90315
# 747/747 [==============================] - 155s 207ms/step - loss: 0.9249 - accuracy: 0.6046 - val_loss: 0.9152 - val_accuracy: 0.6114
# Epoch 17/50
# 747/747 [==============================] - ETA: 0s - loss: 0.9033 - accuracy: 0.6103
# Epoch 17: val_loss did not improve from 0.90315
# 747/747 [==============================] - 153s 205ms/step - loss: 0.9033 - accuracy: 0.6103 - val_loss: 0.9149 - val_accuracy: 0.6044
# Epoch 18/50
# 747/747 [==============================] - ETA: 0s - loss: 0.8998 - accuracy: 0.6155
# Epoch 18: val_loss did not improve from 0.90315
# 747/747 [==============================] - 158s 211ms/step - loss: 0.8998 - accuracy: 0.6155 - val_loss: 0.9045 - val_accuracy: 0.6145
# Epoch 19/50
# 747/747 [==============================] - ETA: 0s - loss: 0.8941 - accuracy: 0.6169
# Epoch 19: val_loss improved from 0.90315 to 0.90089, saving model to best_1d_bilstm_unweighted.keras
# 747/747 [==============================] - 158s 211ms/step - loss: 0.8941 - accuracy: 0.6169 - val_loss: 0.9009 - val_accuracy: 0.6263
# Epoch 20/50
# 747/747 [==============================] - ETA: 0s - loss: 0.8997 - accuracy: 0.6247
# Epoch 20: val_loss improved from 0.90089 to 0.88889, saving model to best_1d_bilstm_unweighted.keras
# 747/747 [==============================] - 154s 206ms/step - loss: 0.8997 - accuracy: 0.6247 - val_loss: 0.8889 - val_accuracy: 0.6271
# Epoch 21/50
# 747/747 [==============================] - ETA: 0s - loss: 0.8911 - accuracy: 0.6217
# Epoch 21: val_loss improved from 0.88889 to 0.88854, saving model to best_1d_bilstm_unweighted.keras
# 747/747 [==============================] - 154s 207ms/step - loss: 0.8911 - accuracy: 0.6217 - val_loss: 0.8885 - val_accuracy: 0.6255
# Epoch 22/50
# 747/747 [==============================] - ETA: 0s - loss: 0.8841 - accuracy: 0.6249
# Epoch 22: val_loss did not improve from 0.88854
# 747/747 [==============================] - 159s 213ms/step - loss: 0.8841 - accuracy: 0.6249 - val_loss: 1.0016 - val_accuracy: 0.5418
# Epoch 23/50
# 747/747 [==============================] - ETA: 0s - loss: 0.8886 - accuracy: 0.6091
# Epoch 23: val_loss improved from 0.88854 to 0.87570, saving model to best_1d_bilstm_unweighted.keras
# 747/747 [==============================] - 162s 217ms/step - loss: 0.8886 - accuracy: 0.6091 - val_loss: 0.8757 - val_accuracy: 0.6317
# Epoch 24/50
# 747/747 [==============================] - ETA: 0s - loss: 0.8783 - accuracy: 0.6232
# Epoch 24: val_loss did not improve from 0.87570
# 747/747 [==============================] - 157s 210ms/step - loss: 0.8783 - accuracy: 0.6232 - val_loss: 0.8761 - val_accuracy: 0.6294
# Epoch 25/50
# 747/747 [==============================] - ETA: 0s - loss: 0.8720 - accuracy: 0.6281
# Epoch 25: val_loss did not improve from 0.87570
# 747/747 [==============================] - 154s 206ms/step - loss: 0.8720 - accuracy: 0.6281 - val_loss: 0.8832 - val_accuracy: 0.6286
# Epoch 26/50
# 747/747 [==============================] - ETA: 0s - loss: 0.8724 - accuracy: 0.6281
# Epoch 26: val_loss did not improve from 0.87570
# 747/747 [==============================] - 154s 206ms/step - loss: 0.8724 - accuracy: 0.6281 - val_loss: 0.8773 - val_accuracy: 0.6333
# Epoch 27/50
# 747/747 [==============================] - ETA: 0s - loss: 0.8641 - accuracy: 0.6313
# Epoch 27: val_loss did not improve from 0.87570
# 747/747 [==============================] - 157s 210ms/step - loss: 0.8641 - accuracy: 0.6313 - val_loss: 0.8765 - val_accuracy: 0.6380
# Epoch 28/50
# 747/747 [==============================] - ETA: 0s - loss: 0.8631 - accuracy: 0.6281
# Epoch 28: val_loss did not improve from 0.87570
# 747/747 [==============================] - 156s 209ms/step - loss: 0.8631 - accuracy: 0.6281 - val_loss: 0.8777 - val_accuracy: 0.6263
# Epoch 29/50
# 747/747 [==============================] - ETA: 0s - loss: 0.8553 - accuracy: 0.6333
# Epoch 29: val_loss did not improve from 0.87570
# 747/747 [==============================] - 151s 203ms/step - loss: 0.8553 - accuracy: 0.6333 - val_loss: 0.8825 - val_accuracy: 0.6364
# Epoch 30/50
# 747/747 [==============================] - ETA: 0s - loss: 0.8481 - accuracy: 0.6356
# Epoch 30: val_loss improved from 0.87570 to 0.87350, saving model to best_1d_bilstm_unweighted.keras
# 747/747 [==============================] - 149s 200ms/step - loss: 0.8481 - accuracy: 0.6356 - val_loss: 0.8735 - val_accuracy: 0.6364
# Epoch 31/50
# 747/747 [==============================] - ETA: 0s - loss: 0.8332 - accuracy: 0.6430
# Epoch 31: val_loss did not improve from 0.87350
# 747/747 [==============================] - 155s 207ms/step - loss: 0.8332 - accuracy: 0.6430 - val_loss: 0.8824 - val_accuracy: 0.6325
# Epoch 32/50
# 747/747 [==============================] - ETA: 0s - loss: 0.8365 - accuracy: 0.6360
# Epoch 32: val_loss improved from 0.87350 to 0.86988, saving model to best_1d_bilstm_unweighted.keras
# 747/747 [==============================] - 158s 212ms/step - loss: 0.8365 - accuracy: 0.6360 - val_loss: 0.8699 - val_accuracy: 0.6255
# Epoch 33/50
# 747/747 [==============================] - ETA: 0s - loss: 0.8383 - accuracy: 0.6328
# Epoch 33: val_loss improved from 0.86988 to 0.86778, saving model to best_1d_bilstm_unweighted.keras
# 747/747 [==============================] - 158s 212ms/step - loss: 0.8383 - accuracy: 0.6328 - val_loss: 0.8678 - val_accuracy: 0.6278
# Epoch 34/50
# 747/747 [==============================] - ETA: 0s - loss: 0.8238 - accuracy: 0.6458
# Epoch 34: val_loss did not improve from 0.86778
# 747/747 [==============================] - 155s 208ms/step - loss: 0.8238 - accuracy: 0.6458 - val_loss: 0.8724 - val_accuracy: 0.6396
# Epoch 35/50
# 747/747 [==============================] - ETA: 0s - loss: 0.8036 - accuracy: 0.6507
# Epoch 35: val_loss improved from 0.86778 to 0.84785, saving model to best_1d_bilstm_unweighted.keras
# 747/747 [==============================] - 154s 207ms/step - loss: 0.8036 - accuracy: 0.6507 - val_loss: 0.8479 - val_accuracy: 0.6575
# Epoch 36/50
# 747/747 [==============================] - ETA: 0s - loss: 0.7970 - accuracy: 0.6579
# Epoch 36: val_loss did not improve from 0.84785
# 747/747 [==============================] - 150s 200ms/step - loss: 0.7970 - accuracy: 0.6579 - val_loss: 0.8676 - val_accuracy: 0.6419
# Epoch 37/50
# 747/747 [==============================] - ETA: 0s - loss: 0.7758 - accuracy: 0.6576
# Epoch 37: val_loss improved from 0.84785 to 0.84175, saving model to best_1d_bilstm_unweighted.keras
# 747/747 [==============================] - 155s 208ms/step - loss: 0.7758 - accuracy: 0.6576 - val_loss: 0.8417 - val_accuracy: 0.6427
# Epoch 38/50
# 747/747 [==============================] - ETA: 0s - loss: 0.7467 - accuracy: 0.6713
# Epoch 38: val_loss improved from 0.84175 to 0.80503, saving model to best_1d_bilstm_unweighted.keras
# 747/747 [==============================] - 156s 209ms/step - loss: 0.7467 - accuracy: 0.6713 - val_loss: 0.8050 - val_accuracy: 0.6638
# Epoch 39/50
# 747/747 [==============================] - ETA: 0s - loss: 0.7060 - accuracy: 0.6927
# Epoch 39: val_loss improved from 0.80503 to 0.80244, saving model to best_1d_bilstm_unweighted.keras
# 747/747 [==============================] - 152s 204ms/step - loss: 0.7060 - accuracy: 0.6927 - val_loss: 0.8024 - val_accuracy: 0.6794
# Epoch 40/50
# 747/747 [==============================] - ETA: 0s - loss: 0.6879 - accuracy: 0.7010
# Epoch 40: val_loss did not improve from 0.80244
# 747/747 [==============================] - 155s 208ms/step - loss: 0.6879 - accuracy: 0.7010 - val_loss: 0.8206 - val_accuracy: 0.6505
# Epoch 41/50
# 747/747 [==============================] - ETA: 0s - loss: 0.6699 - accuracy: 0.7097
# Epoch 41: val_loss improved from 0.80244 to 0.79906, saving model to best_1d_bilstm_unweighted.keras
# 747/747 [==============================] - 157s 210ms/step - loss: 0.6699 - accuracy: 0.7097 - val_loss: 0.7991 - val_accuracy: 0.6693
# Epoch 42/50
# 747/747 [==============================] - ETA: 0s - loss: 0.6613 - accuracy: 0.7170
# Epoch 42: val_loss improved from 0.79906 to 0.79845, saving model to best_1d_bilstm_unweighted.keras
# 747/747 [==============================] - 157s 211ms/step - loss: 0.6613 - accuracy: 0.7170 - val_loss: 0.7985 - val_accuracy: 0.6747
# Epoch 43/50
# 747/747 [==============================] - ETA: 0s - loss: 0.6458 - accuracy: 0.7170
# Epoch 43: val_loss improved from 0.79845 to 0.79222, saving model to best_1d_bilstm_unweighted.keras
# 747/747 [==============================] - 157s 210ms/step - loss: 0.6458 - accuracy: 0.7170 - val_loss: 0.7922 - val_accuracy: 0.6779
# Epoch 44/50
# 747/747 [==============================] - ETA: 0s - loss: 0.6243 - accuracy: 0.7231
# Epoch 44: val_loss improved from 0.79222 to 0.78653, saving model to best_1d_bilstm_unweighted.keras
# 747/747 [==============================] - 156s 209ms/step - loss: 0.6243 - accuracy: 0.7231 - val_loss: 0.7865 - val_accuracy: 0.6740
# Epoch 45/50
# 747/747 [==============================] - ETA: 0s - loss: 0.6119 - accuracy: 0.7308
# Epoch 45: val_loss did not improve from 0.78653
# 747/747 [==============================] - 156s 209ms/step - loss: 0.6119 - accuracy: 0.7308 - val_loss: 0.8067 - val_accuracy: 0.6357
# Epoch 46/50
# 747/747 [==============================] - ETA: 0s - loss: 0.6043 - accuracy: 0.7335
# Epoch 46: val_loss improved from 0.78653 to 0.78245, saving model to best_1d_bilstm_unweighted.keras
# 747/747 [==============================] - 156s 209ms/step - loss: 0.6043 - accuracy: 0.7335 - val_loss: 0.7824 - val_accuracy: 0.6552
# Epoch 47/50
# 747/747 [==============================] - ETA: 0s - loss: 0.5828 - accuracy: 0.7460
# Epoch 47: val_loss did not improve from 0.78245
# 747/747 [==============================] - 155s 208ms/step - loss: 0.5828 - accuracy: 0.7460 - val_loss: 0.7889 - val_accuracy: 0.6630
# Epoch 48/50
# 747/747 [==============================] - ETA: 0s - loss: 0.5542 - accuracy: 0.7591
# Epoch 48: val_loss did not improve from 0.78245
# 747/747 [==============================] - 151s 202ms/step - loss: 0.5542 - accuracy: 0.7591 - val_loss: 0.7884 - val_accuracy: 0.6693
# Epoch 49/50
# 747/747 [==============================] - ETA: 0s - loss: 0.5548 - accuracy: 0.7586
# Epoch 49: val_loss did not improve from 0.78245
# 747/747 [==============================] - 151s 202ms/step - loss: 0.5548 - accuracy: 0.7586 - val_loss: 0.8346 - val_accuracy: 0.6380
# Epoch 50/50
# 747/747 [==============================] - ETA: 0s - loss: 0.5478 - accuracy: 0.7633
# Epoch 50: val_loss did not improve from 0.78245
# 747/747 [==============================] - 150s 201ms/step - loss: 0.5478 - accuracy: 0.7633 - val_loss: 0.7985 - val_accuracy: 0.6740

# %% [markdown]
# ## Test Evaluation

# %%
test_loss, test_accuracy = model.evaluate(
    X_test,
    y_test,
    verbose=1
)

print("===== 1D BILSTM TEST RESULTS =====")

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# 40/40 [==============================] - 5s 111ms/step - loss: 0.8323 - accuracy: 0.6633
# ===== 1D BILSTM TEST RESULTS =====
# Test Loss: 0.8323
# Test Accuracy: 0.6633

# %% [markdown]
# ## Predictions & Confusion Matrix

# %%
from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    ConfusionMatrixDisplay
)

y_pred_prob = model.predict(
    X_test,
    verbose=1
)

y_pred = np.argmax(
    y_pred_prob,
    axis=1
)

cm = confusion_matrix(
    y_test,
    y_pred
)

print("===== BILSTM CONFUSION MATRIX =====")
print(cm)
# Out:
# 40/40 [==============================] - 6s 103ms/step
# ===== BILSTM CONFUSION MATRIX =====
# [[672  14  74   2]
#  [ 27  53  32   1]
#  [221  33 105   4]
#  [ 19   1   3  19]]

# %% [markdown]
# ## Classification Report

# %%
print("===== BILSTM CLASSIFICATION REPORT =====")

print(
    classification_report(
        y_test,
        y_pred,
        digits=4
    )
)
# Out:
# ===== BILSTM CLASSIFICATION REPORT =====
#               precision    recall  f1-score   support
#
#            0     0.7157    0.8819    0.7901       762
#            1     0.5248    0.4690    0.4953       113
#            2     0.4907    0.2893    0.3640       363
#            3     0.7308    0.4524    0.5588        42
#
#     accuracy                         0.6633      1280
#    macro avg     0.6155    0.5231    0.5521      1280
# weighted avg     0.6355    0.6633    0.6356      1280

# %% [markdown]
# ## Confusion Matrix Visualization

# %%
class_names = [
    "N",
    "A",
    "O",
    "~"
]

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=class_names
)

fig, ax = plt.subplots(
    figsize=(7, 7)
)

disp.plot(
    ax=ax,
    cmap="Blues",
    values_format="d"
)

plt.title("1D BiLSTM Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Accuracy Curves

# %%
plt.figure(figsize=(8, 5))

plt.plot(
    history.history["accuracy"],
    label="Training Accuracy"
)

plt.plot(
    history.history["val_accuracy"],
    label="Validation Accuracy"
)

plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("1D BiLSTM Accuracy")

plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Loss Curve

# %%
plt.figure(figsize=(8, 5))

plt.plot(
    history.history["loss"],
    label="Training Loss"
)

plt.plot(
    history.history["val_loss"],
    label="Validation Loss"
)

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("1D BiLSTM Loss")

plt.legend()
plt.grid(True)
plt.show()
